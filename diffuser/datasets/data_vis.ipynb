# %%
import numpy as np

# file_path = "/data/prisoner_datasets/october_datasets/4_detect/train/seed_100_known_44_unknown_33.npz"
file_path = "/data/prisoner_datasets/october_datasets/3_detect/test/seed_300_known_44_unknown_33.npz"

f = np.load(file_path)

print(f["red_locations"]) # unnormalized
# print(f["detected_locations"]) # normalized?? Why.. lmao
# Out:
# [[2280 2280]
#  [2273 2279]
#  [2266 2279]
#  [2259 2278]
#  [2257 2278]
#  [2252 2273]
#  [2247 2268]
#  [2242 2263]
#  [2237 2258]
#  [2236 2257]
#  [2231 2252]
#  [2226 2247]
#  [2221 2242]
#  [2216 2237]
#  [2215 2236]
#  [2208 2236]
#  [2200 2236]
#  [2193 2236]
#  [2188 2231]
#  [2183 2226]
#  [2178 2221]
#  [2173 2216]
#  [2172 2215]
#  [2164 2215]
#  [2156 2215]
#  [2151 2215]
#  [2146 2210]
#  [2141 2205]
#  [2136 2200]
#  [2131 2195]
#  [2129 2193]
#  [2124 2188]
#  [2119 2183]
#  [2114 2178]
#  [2109 2173]
#  [2108 2172]
#  [2103 2167]
#  [2098 2162]
#  [2093 2157]
#  [2088 2152]
#  [2087 2151]
#  [2082 2146]
#  [2077 2141]
#  [2072 2136]
#  [2067 2131]
#  [2065 2129]
#  [2060 2124]
#  [2055 2119]
#  [2050 2114]
#  [2045 2109]
#  [2044 2108]
#  [2039 2103]
#  [2034 2098]
#  [2029 2093]
#  [2024 2088]
#  [2023 2087]
#  [2018 2082]
#  [2013 2077]
#  [2008 2071]
#  [2003 2066]
#  [2002 2065]
#  [1997 2065]
#  [1996 2064]
#  [1989 2060]
#  [1982 2056]
#  [1975 2053]
# ...
